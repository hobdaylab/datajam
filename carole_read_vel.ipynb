# %%
data = "Carole_eth_gly-vel-1.xyz"
import numpy as np

# %%
index_1 = np.arange(2,100,12)
index_1
# Out:
# array([ 2, 14, 26, 38, 50, 62, 74, 86, 98])

# %%
with open(data, "r") as f:
    for i,line in enumerate(f):
        print(line)
        if i == 20:
            break
# Out:
#       10
#
#  i =        0, time =        0.000, E =       -46.6836361009
#
#   C        -0.0000426071       -0.0001424658       -0.0001009107
#
#   O        -0.0001169493        0.0002689288       -0.0002157501
#
#   H         0.0005537830        0.0011883012       -0.0004528939
#
#   H         0.0002605033        0.0003665230       -0.0004263031
#
#   C         0.0003158175       -0.0000638648       -0.0001049505
#
#   H         0.0006478037       -0.0010586063       -0.0007284192
#
#   H        -0.0004299181       -0.0008202737        0.0006830263
#
#   O        -0.0001069765       -0.0000997520        0.0003671292
#
#   H        -0.0003594433       -0.0003379690        0.0011484419
#
#   H        -0.0003738716        0.0004352718       -0.0001736872
#
#       10
#
#  i =        1, time =        0.550, E =       -46.6897784309
#
#   C         0.0000502410        0.0001700849       -0.0002350868
#
#   O        -0.0002859371       -0.0000193147       -0.0000954225
#
#   H         0.0005812105        0.0014701088       -0.0004319453
#
#   H         0.0004623704        0.0006122624       -0.0005358229
#
#   C         0.0002185369       -0.0002960261       -0.0003574825
#
#   H         0.0005766513       -0.0012531393       -0.0007847991
#
#   H        -0.0005671921       -0.0008754212        0.0004586963

# %%
atom_1 = []
with open(data, "r") as f:
    for i,line in enumerate(f):
        line=line.split()
        if i in index_1:
            print(line)
            atom_1.append(line)
# Out:
# ['C', '-0.0000426071', '-0.0001424658', '-0.0001009107']
# ['C', '0.0000502410', '0.0001700849', '-0.0002350868']
# ['C', '0.0001454325', '0.0004751584', '-0.0003655272']
# ['C', '0.0002375010', '0.0007566057', '-0.0004892592']
# ['C', '0.0003187720', '0.0010020269', '-0.0006018336']
# ['C', '0.0003829210', '0.0011998056', '-0.0006998080']
# ['C', '0.0004311352', '0.0013504038', '-0.0007820385']
# ['C', '0.0004618321', '0.0014547380', '-0.0008491490']
# ['C', '0.0004790316', '0.0015182679', '-0.0009006089']

# %%
limes = []

with open(data, "r") as f:
    for i,line in enumerate(f):
        line=line.split()
        if len(line) == 4:
            print(line)

            limes.append(line)
        if i == 21:
            break
# Out:
# ['C', '-0.0000426071', '-0.0001424658', '-0.0001009107']
# ['O', '-0.0001169493', '0.0002689288', '-0.0002157501']
# ['H', '0.0005537830', '0.0011883012', '-0.0004528939']
# ['H', '0.0002605033', '0.0003665230', '-0.0004263031']
# ['C', '0.0003158175', '-0.0000638648', '-0.0001049505']
# ['H', '0.0006478037', '-0.0010586063', '-0.0007284192']
# ['H', '-0.0004299181', '-0.0008202737', '0.0006830263']
# ['O', '-0.0001069765', '-0.0000997520', '0.0003671292']
# ['H', '-0.0003594433', '-0.0003379690', '0.0011484419']
# ['H', '-0.0003738716', '0.0004352718', '-0.0001736872']
# ['C', '0.0000502410', '0.0001700849', '-0.0002350868']
# ['O', '-0.0002859371', '-0.0000193147', '-0.0000954225']
# ['H', '0.0005812105', '0.0014701088', '-0.0004319453']
# ['H', '0.0004623704', '0.0006122624', '-0.0005358229']
# ['C', '0.0002185369', '-0.0002960261', '-0.0003574825']
# ['H', '0.0005766513', '-0.0012531393', '-0.0007847991']
# ['H', '-0.0005671921', '-0.0008754212', '0.0004586963']
# ['O', '-0.0000305877', '0.0001458944', '0.0006099893']

# %%
l_conf = 10
ix = 0

limes[ix:ix+10]
# Out:
# [['C', '-0.0000426071', '-0.0001424658', '-0.0001009107'],
#  ['O', '-0.0001169493', '0.0002689288', '-0.0002157501'],
#  ['H', '0.0005537830', '0.0011883012', '-0.0004528939'],
#  ['H', '0.0002605033', '0.0003665230', '-0.0004263031'],
#  ['C', '0.0003158175', '-0.0000638648', '-0.0001049505'],
#  ['H', '0.0006478037', '-0.0010586063', '-0.0007284192'],
#  ['H', '-0.0004299181', '-0.0008202737', '0.0006830263'],
#  ['O', '-0.0001069765', '-0.0000997520', '0.0003671292'],
#  ['H', '-0.0003594433', '-0.0003379690', '0.0011484419'],
#  ['H', '-0.0003738716', '0.0004352718', '-0.0001736872']]

# %%
with open(data, "r") as f:
    for i,line in enumerate(f):
        line=line.split()
        if len(line) != 4:
            print(line)
        if i == 21:
            break
# Out:
# ['10']
# ['i', '=', '0,', 'time', '=', '0.000,', 'E', '=', '-46.6836361009']
# ['10']
# ['i', '=', '1,', 'time', '=', '0.550,', 'E', '=', '-46.6897784309']
